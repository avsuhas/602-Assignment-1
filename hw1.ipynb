# %%
import pandas as pd
import numpy as np

# %%
file_loc = "hw1.xlsx"
df = pd.read_excel(file_loc, index_col=None, na_values=['NA'], parse_cols = "A,C:AA")
print(df)
# Out:
#                  United \nAirlines  Microsoft  Hertz Car \nRental  \
# Hans Pakes                     1.0        1.0                 0.0
# Christina Price                1.0        1.0                 0.0
# Ann Bryant                     1.0        1.0                 0.0
# Walter Allen                   0.0        0.0                 1.0
# Jamal Kalifa                   0.0        0.0                 1.0
# Jesse Adams                    0.0        0.0                 1.0
# Ben Hassine                    0.0        0.0                 0.0
# Wallace Wilson                 0.0        0.0                 0.0
# Karm Bensaid                   0.0        0.0                 0.0
# Carl Louis                     0.0        0.0                 0.0
# Mark Davis                     0.0        0.0                 0.0
# Clark Webster                  0.0        0.0                 0.0
# Adam Phillips                  0.0        0.0                 0.0
# ...

# %%
df1 = df[:]

# %%
df1
# Out:
#                  United \nAirlines  Microsoft  Hertz Car \nRental  \
# Hans Pakes                     1.0        1.0                 0.0
# Christina Price                1.0        1.0                 0.0
# Ann Bryant                     1.0        1.0                 0.0
# Walter Allen                   0.0        0.0                 1.0
# Jamal Kalifa                   0.0        0.0                 1.0
# Jesse Adams                    0.0        0.0                 1.0
# Ben Hassine                    0.0        0.0                 0.0
# Wallace Wilson                 0.0        0.0                 0.0
# Karm Bensaid                   0.0        0.0                 0.0
# Carl Louis                     0.0        0.0                 0.0
# Mark Davis                     0.0        0.0                 0.0
# Clark Webster                  0.0        0.0                 0.0
# Adam Phillips                  0.0        0.0                 0.0
# ...

# %%
df1
# Out:
#                  United \nAirlines  Microsoft  Hertz Car \nRental  \
# Hans Pakes                     1.0        1.0                 0.0
# Christina Price                1.0        1.0                 0.0
# Ann Bryant                     1.0        1.0                 0.0
# Walter Allen                   0.0        0.0                 1.0
# Jamal Kalifa                   0.0        0.0                 1.0
# Jesse Adams                    0.0        0.0                 1.0
# Ben Hassine                    0.0        0.0                 0.0
# Wallace Wilson                 0.0        0.0                 0.0
# Karm Bensaid                   0.0        0.0                 0.0
# Carl Louis                     0.0        0.0                 0.0
# Mark Davis                     0.0        0.0                 0.0
# Clark Webster                  0.0        0.0                 0.0
# Adam Phillips                  0.0        0.0                 0.0
# ...
